# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.font_manager as fm

# # this is to update the overall font
# plt.rcParams.update({
#     #"text.usetex": True,
# #     "font.family": "serif",
# #     "font.sans-serif": "Computer Modern",
#     "font.family": "sans-serif",
#     "font.sans-serif": "Poppins",
# })

poppins_font_path = "/Users/robertsalzwedel/Library/Fonts/Poppins-Regular.ttf"  # Change to the correct path if necessary

# Add the font to Matplotlib
fm.fontManager.addfont(poppins_font_path)
plt.rcParams['font.family'] = 'Poppins'  # Use Poppins as the default font


# input data 
data = {'labels': ['A', 'B', 'C', 'D'],
        'values': [20, 35, 25, 20]}
df = pd.DataFrame(data)


# not sure what this is for
#sns.set_style("whitegrid")

# define palette
palette_color = sns.color_palette(['#d2b48c', '#deb887', '#bc8f8f', '#f4a460', '#cd853f'])

# figure definition
fig, ax = plt.subplots(figsize=(7,6))
ax.pie(df['values'], labels=None, autopct='%1.0f%%',colors=palette_color,wedgeprops={'edgecolor': '#f4ecd8'})

# choose background color
fig.patch.set_facecolor('#f4ecd8')  # Light tan for the figure background
ax.set_facecolor('#f4ecd8')  # Light tan for the axes background

# legend
legend = ax.legend(df['labels'],loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), frameon=False,fontsize = 12)

# Add title
plt.title('Climate Pie Chart', fontsize=18, color='darkred')

# Add a footnote-like text to the bottom left corner
ax.text(0.01, 0.01, 'This is where the References are supposed to go.', 
        fontsize=10, 
        color='gray', 
        ha='left', 
        va='bottom', 
        transform=ax.transAxes)

plt.show()
plt.tight_layout()
fig.savefig("Test.png")

# %%
import matplotlib.font_manager as fm

# List all fonts and check if Poppins is included
font_list = [f.name for f in fm.fontManager.ttflist]
print("Available fonts:")
for font in font_list:
    pass
    #print(font)
    
# Check specifically for Poppins
if "Poppins" in font_list:
    print("Poppins is available!")
else:
    print("Poppins is not available.")
# Out:
# Available fonts:
# Poppins is not available.

# %%
import matplotlib.font_manager as fm

font_list = [f.name for f in fm.fontManager.ttflist]
print("Available fonts:")
print(font_list)
# Out:
# Available fonts:
# ['DejaVu Sans', 'DejaVu Sans Display', 'DejaVu Sans', 'DejaVu Serif', 'DejaVu Serif Display', 'STIXNonUnicode', 'STIXSizeOneSym', 'STIXSizeTwoSym', 'STIXGeneral', 'STIXNonUnicode', 'STIXGeneral', 'DejaVu Sans', 'DejaVu Sans Mono', 'DejaVu Serif', 'cmmi10', 'STIXSizeThreeSym', 'STIXSizeTwoSym', 'STIXSizeFourSym', 'DejaVu Sans Mono', 'STIXNonUnicode', 'DejaVu Sans Mono', 'cmtt10', 'cmr10', 'cmex10', 'STIXNonUnicode', 'cmb10', 'STIXSizeFourSym', 'STIXGeneral', 'cmss10', 'STIXSizeThreeSym', 'cmsy10', 'STIXGeneral', 'STIXSizeFiveSym', 'DejaVu Serif', 'DejaVu Serif', 'STIXSizeOneSym', 'DejaVu Sans Mono', 'DejaVu Sans', 'Avenir Next', 'Nanum Gothic', 'Times New Roman', 'Annai MN', 'Noto Sans Lydian', 'Hiragino Sans CNS', 'Noto Sans Myanmar', 'Hiragino Mincho ProN', 'Noto Sans Batak', 'Cambay Devanagari', 'Noto Sans Gothic', 'System Font', 'Noto Sans Hanifi Rohingya', 'Webdings', 'Kannada MN', 'KoHo', 'Tamil Sangam MN', 'Toppan Bunkyu Midashi Gothic', 'Modak', 'STIXGeneral', 'Mshtakan', 'ITF Devanagari', '.SF Arabic Rounded', 'Noto Sans Khudawadi', 'STIXNonUnicode', 'Noto Sans Sora Sompeng', '.SF Compact', 'Noto Sans New Tai Lue', 'Katari', 'Georgia', 'Geeza Pro', 'Nanum Myeongjo', 'Noto Sans Coptic', 'Arial', 'Noto Sans Hatran', 'Noto Sans Tai Le', 'Padyakke Expanded One', 'DIN Alternate', 'Hoefler Text', 'Charm', 'Gujarati MT', 'PilGi', 'Sama Devanagari', 'Toppan Bunkyu Midashi Mincho', 'Krungthep', 'Academy Engraved LET', 'Kohinoor Gujarati', 'Trebuchet MS', 'Noto Sans Gunjala Gondi', 'STHeiti', 'Noto Serif Balinese', 'Noto Sans Takri', 'Charmonman', 'Noto Sans Lepcha', 'Noto Sans Mro', 'Telugu MN', 'Arial Unicode MS', 'Arial Narrow', 'LingWai TC', 'Baloo Bhaijaan', '.Aqua Kana', 'Kailasa', 'Devanagari MT', 'Thonburi', 'STHeiti', 'Yuanti SC', 'HeadLineA', 'Hiragino Sans', 'Hiragino Sans', 'Bangla MN', 'Noto Serif Yezidi', 'Verdana', 'SignPainter', 'STIXIntegralsUp', 'Rockwell', 'Noto Sans Meroitic', 'Wawati TC', 'STIXGeneral', 'Noto Nastaliq Urdu', '.ThonburiUI', 'Symbol', 'Baloo Da 2', 'Avenir Next Condensed', 'Noto Sans Old Turkic', 'Apple Symbols', 'Noto Sans Inscriptional Parthian', 'Noto Sans Tirhuta', 'HanziPen SC', 'Mukta', 'Beirut', 'Oriya Sangam MN', 'AppleGothic', 'Lava Devanagari', 'Times New Roman', 'Sukhumvit Set', 'Noto Sans Buhid', 'Khmer MN', 'Nadeem', 'Baghdad', 'Baloo Thambi 2', 'Shree Devanagari 714', 'Big Caslon', 'Mukta Malar', 'Palatino', 'Arial', 'Tiro Devanagari Sanskrit', 'Chalkboard SE', 'Noto Sans Canadian Aboriginal', 'Noto Sans Cuneiform', 'Noto Sans Manichaean', 'Noto Sans Mahajani', 'AkayaKanadaka', 'STFangsong', 'Mukta Mahee', 'Didot', 'BiauKai', 'Tsukushi B Round Gothic', 'Baskerville', 'PT Sans', 'Noto Sans Inscriptional Pahlavi', 'Baloo Bhai 2', 'Chalkduster', 'Comic Sans MS', 'Gurmukhi MN', 'Tiro Devanagari Hindi', 'Impact', 'BM Hanna 11yrs Old', 'Noto Serif Myanmar', 'Noto Sans Old Italic', 'Kohinoor Devanagari', 'Tamil MN', 'Arial Unicode MS', 'Chalkboard', 'Sana', 'PT Serif Caption', 'Wingdings', 'Noto Sans Warang Citi', 'Snell Roundhand', 'Al Tarikh', 'Noto Sans Modi', 'Athelas', 'Diwan Thuluth', 'Wingdings 3', 'Jaini Purva', 'PCMyungjo', 'Iowan Old Style', 'Arial', 'Kefa', 'Noto Sans Buginese', 'Noto Sans Imperial Aramaic', 'SimSong', 'STIXSizeFourSym', 'Farah', '.SF NS Mono', 'Farisi', 'Heiti TC', 'Euphemia UCAS', '.SF Compact Rounded', 'New Peninim MT', 'BM Jua', 'Sama Malayalam', 'Party LET', 'Comic Sans MS', 'Trebuchet MS', 'October Compressed Devanagari', 'STIXSizeFiveSym', 'STIXIntegralsUpSm', 'Arial Narrow', 'Noto Sans Pahawh Hmong', 'Noto Sans Old Hungarian', 'Myanmar MN', 'Malayalam MN', 'Tiro Gurmukhi', 'Trattatello', '.SF NS Rounded', 'STIXNonUnicode', 'STIX Two Text', 'STIX Two Math', 'Kohinoor Telugu', 'Noto Sans Masaram Gondi', 'Courier New', 'Noto Sans Bhaiksuki', 'Noto Sans Javanese', 'Noto Sans Linear A', 'STIXGeneral', 'Mali', 'Verdana', 'Noto Sans Sundanese', 'Apple Braille', 'Apple Braille', 'Baloo Bhaina 2', 'Wingdings 2', 'Hoefler Text', 'Hiragino Maru Gothic Pro', 'Not ...
